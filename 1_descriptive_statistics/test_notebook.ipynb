# %%
import sys

sys.path.insert(1, 'C:/Users/simon/Desktop/github_projects/hands_on_statistics/zz_help_functions/')
from database_connection_functions import get_from_oecd


test = get_from_oecd('EAG_TRANS_DURUNEMP')

test
# Out:
#       COUNTRY                            Country ISC11A  \
# 0         AUS                          Australia      T
# 1         AUT                            Austria      T
# 2         BEL                            Belgium      T
# 3         CAN                             Canada      T
# 4         CZE                            Czechia      T
# ...       ...                                ...    ...
# 64854     E23  European Union 23 members in OECD      T
# 64855     E23  European Union 23 members in OECD      T
# 64856     E23  European Union 23 members in OECD      T
# 64857     E23  European Union 23 members in OECD      T
# 64858     E23  European Union 23 members in OECD      T
#
#                   ISCED-A 2011 SEX Gender     AGE                    Age  \
# 0      All levels of education   T  Total       T  Total: All age groups
# 1      All levels of education   T  Total       T  Total: All age groups
# ...
